# %% [markdown]
# # Linear Regression
# ### Regression analysis is a form of predictive modelling technique which investigates
# ### the relationship between a dependent and independent variable.

# %% [markdown]
# # What Linear Regression is used for?
# ### .It is used in Market Research and the study of customer survey results
# ### .It is used for studying the performance of the engines of automobiles
# ### .It is used in deciding the effective price of any goods
# ### .It is used in Astronomy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as seabornInstance
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
dataset=pd.read_csv(r"C:\Users\H\Downloads\weather_dataset.csv")

# %%
dataset.tail()
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 361           76.0        SSE         NW           7.0  ...           15
# 362           48.0        NNW        NNW           2.0  ...           22
# 363           43.0        ENE        ENE          11.0  ...           47
# 364           46.0        SSW        WNW           6.0  ...           39
# 365           78.0         NW        WNW          31.0  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
dataset.shape
# Out:
# (366, 22)

# %%
dataset.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
dataset.plot(x='MinTemp',y='MaxTemp',style='o')
plt.title('MinTemp vs MaxTemp')
plt.xlabel('MinTemp')
plt.ylabel('MaxTemp')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.tight_layout()
seabornInstance.distplot(dataset['MaxTemp'])
plt.show()
# Out:
# C:\Users\H\AppData\Local\Temp\ipykernel_13092\3259242927.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   seabornInstance.distplot(dataset['MaxTemp'])

# %% [markdown]
# ## **Data splicing**

# %%
X=dataset['MinTemp'].values.reshape(-1,1)
y=dataset['MaxTemp'].values.reshape(-1,1)
#X

# %% [markdown]
# ## **Training and Testing data**

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.shape
# Out:
# (292, 1)

# %% [markdown]
# # Training the algorithm

# %%
regressor=LinearRegression()  # create class LinearRegression
regressor.fit(X_train,y_train) # training the algorithm
# Out:
# LinearRegression()

# %% [markdown]
# # To retrieve the intercept:

# %%
print('Intercept: ',regressor.intercept_)
# Out:
# Intercept:  [14.56202411]

# %%
print('Coefficient: ',regressor.coef_)
# Out:
# Coefficient:  [[0.81953755]]

# %% [markdown]
# # Predictions

# %%
y_predictions=regressor.predict(X_test)
#y_predictions

# %%
df=pd.DataFrame({'Actual':y_test.flatten(),'Predicted':y_predictions.flatten()})
df
# Out:
#     Actual  Predicted
# 0     25.2  23.413030
# 1     11.5  13.086857
# 2     21.1  27.264856
# 3     22.2  25.461874
# 4     20.4  26.937041
# ..     ...        ...
# 69    18.9  20.216833
# 70    22.8  27.674625
# 71    16.1  21.446140
# 72    25.1  24.970151
# 73    12.2  14.070302
#
# [74 rows x 2 columns]

# %%
df1=df.head(25)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major',linestyle='-',linewidth='0.5',color='green')
plt.grid(which='minor',linestyle=':',linewidth='0.5',color='black')
plt.show()

# %%
plt.scatter(X_test,y_test,color='gray')
plt.plot(X_test,y_predictions,color='red',linewidth=2)
plt.show()

# %% [markdown]
# # Evaluate the performance of the algorithm

# %%
print('Mean Absolute Error', metrics.mean_absolute_error(y_test, y_predictions))
print('Mean Squared Error', metrics.mean_squared_error(y_test, y_predictions))
print('Root Mean Squared Error', metrics.root_mean_squared_error(y_test, y_predictions))
# Out:
# Mean Absolute Error 3.5094353112899594
# Mean Squared Error 17.011877668640622
# Root Mean Squared Error 4.124545753006096

# %% [markdown]
# # Evaluation
# </b></h>
# MAE (3.51), MSE (17.01), RMSE (4.12) quantified that inconsistency numerically. RMSE of ~4°C tells us the model is reasonably aligned with reality but not highly precise.<b/></h>

# %% [markdown]
# ## **Conclusion**
# </h></b>The simple linear regression model captures the general positive relationship between MinTemp and MaxTemp, but with an average prediction error of ~4°C, it has moderate accuracy.</h></b>
